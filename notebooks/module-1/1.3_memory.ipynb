# %%
from dotenv import load_dotenv

load_dotenv()
# Out:
# True

# %% [markdown]
# ## No memory

# %%
from langchain.agents import create_agent


agent = create_agent(
    "ollama:llama3.1:8b"
)

# %%
from langchain.messages import HumanMessage

question = HumanMessage(content="Hello my name is Seán and my favourite colour is green")

response = agent.invoke(
    {"messages": [question]} 
)

# %%
from pprint import pprint

pprint(response)
# Out:
# {'messages': [HumanMessage(content='Hello my name is Seán and my favourite colour is green', additional_kwargs={}, response_metadata={}, id='1350d0da-3134-479d-adc4-8d2207bd2335'),
#               AIMessage(content="Hello Seán! Nice to meet you! Green is a great colour, very calming and natural. What is it about green that you like the most? Is it the way it reminds you of nature, or do you have a particular association with the colour that's special to you?", additional_kwargs={}, response_metadata={'model': 'llama3.1:8b', 'created_at': '2026-08-28T20:18:10.745767Z', 'done': True, 'done_reason': 'stop', 'total_duration': 25420917800, 'load_duration': 15530560900, 'prompt_eval_count': 22, 'prompt_eval_duration': 1230910000, 'eval_count': 58, 'eval_duration': 8651741000, 'logprobs': None, 'model_name': 'llama3.1:8b', 'model_provider': 'ollama'}, id='lc_run--01a04a05-6f6a-7131-9580-45b2a49cb7da-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 22, 'output_tokens': 58, 'total_tokens': 80})]}

# %%
question = HumanMessage(content="What's my favourite colour?")

response = agent.invoke(
    {"messages": [question]} 
)

pprint(response)
# Out:
# {'messages': [HumanMessage(content="What's my favourite colour?", additional_kwargs={}, response_metadata={}, id='4ca16912-63be-4a4b-b366-b34b4fb8d78d'),
#               AIMessage(content="Unfortunately, I'm a large language model, I don't have any information about your personal preferences or favourite colours (yet!). We've just started our conversation, and I don't have any prior knowledge about you.\n\nWould you like to share your favourite colour with me, or would you like me to help you discover some new colours?", additional_kwargs={}, response_metadata={'model': 'llama3.1:8b', 'created_at': '2026-08-28T20:21:40.1327456Z', 'done': True, 'done_reason': 'stop', 'total_duration': 12497749700, 'load_duration': 7324000, 'prompt_eval_count': 16, 'prompt_eval_duration': 937466000, 'eval_count': 68, 'eval_duration': 10538279000, 'logprobs': None, 'model_name': 'llama3.1:8b', 'model_provider': 'ollama'}, id='lc_run--01a04a08-d3d0-7cd1-a359-0ea7278ba440-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 16, 'output_tokens': 68, 'total_tokens': 84})]}

# %% [markdown]
# ## Memory

# %%
from langgraph.checkpoint.memory import InMemorySaver  


agent = create_agent(
    "ollama:llama3.1:8b",
    checkpointer=InMemorySaver(),  
)

# %%
from langchain.messages import HumanMessage

question = HumanMessage(content="Hello my name is Seán and my favourite colour is green")
config = {"configurable": {"thread_id": "1"}}

response = agent.invoke(
    {"messages": [question]},
    config,  
)

# %%
pprint(response)
# Out:
# {'messages': [HumanMessage(content='Hello my name is Seán and my favourite colour is green', additional_kwargs={}, response_metadata={}, id='ea7fce92-f0a8-43fe-97f0-803318dd5980'),
#               AIMessage(content="Top o' the morning to you, Seán! Nice to meet you! Green is a fantastic colour, by the way. Very fitting for the Emerald Isle, don't you think? What is it about green that you like the most? Is it the calming effect it has, or perhaps it reminds you of a special place or memory?", additional_kwargs={}, response_metadata={'model': 'llama3.1:8b', 'created_at': '2026-08-28T20:30:18.8320538Z', 'done': True, 'done_reason': 'stop', 'total_duration': 11902646700, 'load_duration': 15504800, 'prompt_eval_count': 22, 'prompt_eval_duration': 1456253000, 'eval_count': 70, 'eval_duration': 10417575000, 'logprobs': None, 'model_name': 'llama3.1:8b', 'model_provider': 'ollama'}, id='lc_run--01a04a10-c044-7f82-8884-5659344ecde4-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 22, 'output_tokens': 70, 'total_tokens': 92})]}

# %%
question = HumanMessage(content="What's my favourite colour?")

response = agent.invoke(
    {"messages": [question]},
    config,  
)

pprint(response)
# Out:
# {'messages': [HumanMessage(content='Hello my name is Seán and my favourite colour is green', additional_kwargs={}, response_metadata={}, id='ea7fce92-f0a8-43fe-97f0-803318dd5980'),
#               AIMessage(content="Top o' the morning to you, Seán! Nice to meet you! Green is a fantastic colour, by the way. Very fitting for the Emerald Isle, don't you think? What is it about green that you like the most? Is it the calming effect it has, or perhaps it reminds you of a special place or memory?", additional_kwargs={}, response_metadata={'model': 'llama3.1:8b', 'created_at': '2026-08-28T20:30:18.8320538Z', 'done': True, 'done_reason': 'stop', 'total_duration': 11902646700, 'load_duration': 15504800, 'prompt_eval_count': 22, 'prompt_eval_duration': 1456253000, 'eval_count': 70, 'eval_duration': 10417575000, 'logprobs': None, 'model_name': 'llama3.1:8b', 'model_provider': 'ollama'}, id='lc_run--01a04a10-c044-7f82-8884-5659344ecde4-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 22, 'output_tokens': 70, 'total_tokens': 92}),
#               HumanMessage(content="What's my favourite colour?", additional_kwargs={}, response_metadata={}, id='1dafb6bb-5d78-4071-b26e-81083333fdf5'),
#               AIMessage(content="It's green! You told me just a minute ago!", additional_kwargs={}, response_metadata={'model': 'llama3.1:8b', 'created_at': '2026-08-28T20:31:43.5663123Z', 'done': True, 'done_reason': 'stop', 'total_duration': 4141825700, 'load_duration': 6314400, 'prompt_eval_count': 107, 'prompt_eval_duration': 2235193000, 'eval_count': 13, 'eval_duration': 1893139000, 'logprobs': None, 'model_name': 'llama3.1:8b', 'model_provider': 'ollama'}, id='lc_run--01a04a12-299a-7502-9398-a2a614e238dc-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 107, 'output_tokens': 13, 'total_tokens': 120})]}
