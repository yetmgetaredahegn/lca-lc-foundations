# %% [markdown]
# ## Tool definition

# %%
from dotenv import load_dotenv

load_dotenv()
# Out:
# True

# %%
from langchain.tools import tool

@tool
def square_root(x: float) -> float:
    """Calculate the square root of a number"""
    return x ** 0.5

# %%
@tool("square_root")
def tool1(x: float) -> float:
    """Calculate the square root of a number"""
    return x ** 0.5

# %%
@tool("square_root", description="Calculate the square root of a number")
def tool1(x: float) -> float:
    return x ** 0.5

# %%
tool1.invoke({"x": 467})
# Out:
# 21.61018278497431

# %% [markdown]
# ## Adding to agents

# %%
from langchain.agents import create_agent

agent = create_agent(
    model="ollama:llama3.1:8b",
    tools=[tool1],
    system_prompt="You are an arithmetic wizard. Use your tools to calculate the square root and square of any number."
)

# %%
from langchain.messages import HumanMessage

question = HumanMessage(content="What is the square root of 467?")

response = agent.invoke(
    {"messages": [question]}
)

print(response['messages'][-1].content)
# Out:
# The square root of 467 is approximately 21.61.

# %%
from pprint import pprint

pprint(response['messages'])
# Out:
# [HumanMessage(content='What is the square root of 467?', additional_kwargs={}, response_metadata={}, id='79070042-e0f2-458f-9fbd-9bd1d4ea761f'),
#  AIMessage(content='', additional_kwargs={}, response_metadata={'model': 'llama3.1:8b', 'created_at': '2026-08-28T18:36:25.9735189Z', 'done': True, 'done_reason': 'stop', 'total_duration': 12846238300, 'load_duration': 10343340300, 'prompt_eval_count': 181, 'prompt_eval_duration': 482757000, 'eval_count': 17, 'eval_duration': 2014234000, 'logprobs': None, 'model_name': 'llama3.1:8b', 'model_provider': 'ollama'}, id='lc_run--01a049a8-79c5-71e1-9296-2bf182466a41-0', tool_calls=[{'name': 'square_root', 'args': {'x': 467}, 'id': '180a4894-1dc7-4991-a286-18ffa56e6381', 'type': 'tool_call'}], invalid_tool_calls=[], usage_metadata={'input_tokens': 181, 'output_tokens': 17, 'total_tokens': 198}),
#  ToolMessage(content='21.61018278497431', name='square_root', id='e8ee01c8-a68c-4adc-9267-8e81d724b9b8', tool_call_id='180a4894-1dc7-4991-a286-18ffa56e6381'),
#  AIMessage(content='The square root of 467 is approximately 21.61.', additional_kwargs={}, response_metadata={'model': 'llama3.1:8b', 'created_at': '2026-08-28T18:36:27.8480417Z', 'done': True, 'done_reason': 'stop', 'total_duration': 1860625300, 'load_duration': 4276500, 'prompt_eval_count': 119, 'prompt_eval_duration': 292613000, 'eval_count': 14, 'eval_duration': 1550338000, 'logprobs': None, 'model_name': 'llama3.1:8b', 'model_provider': 'ollama'}, id='lc_run--01a049a8-ac02-7690-ae4d-6149de7e632d-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 119, 'output_tokens': 14, 'total_tokens': 133})]

# %%
print(response["messages"][1].tool_calls)
# Out:
# [{'name': 'square_root', 'args': {'x': 467}, 'id': '180a4894-1dc7-4991-a286-18ffa56e6381', 'type': 'tool_call'}]
