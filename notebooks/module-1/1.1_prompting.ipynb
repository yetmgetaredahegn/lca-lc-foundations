# %% [markdown]
# ## Basic prompting

# %%
from dotenv import load_dotenv

load_dotenv()
# Out:
# True

# %%
from langchain.agents import create_agent
from langchain.messages import HumanMessage

agent = create_agent("ollama:llama3.1:8b")

question = HumanMessage(content="What's the capital of the moon?")

response = agent.invoke(
    {"messages": [question]}
)

print(response['messages'][1].content)
# Out:
# There is no capital city on the moon. The moon is a natural satellite that orbits the Earth, and it does not have a political government or a capital city. It's a rocky, airless body with no human habitation or infrastructure.
#
# So, there isn't a capital of the moon to speak of! Is there anything else I can help with?

# %%
system_prompt = "You are a science fiction writer, create a capital city at the users request."

scifi_agent = create_agent(
    model="ollama:llama3.1:8b",
    system_prompt=system_prompt
)

response = scifi_agent.invoke(
    {"messages": [question]}
)

print(response['messages'][1].content)
# Out:
# What a great question!
#
# In the year 2157, humanity established its first lunar colony, and over time, it evolved into a thriving, self-sustaining city that became the capital of the Moon. I'm thrilled to introduce you to...
#
# **Lunaria**
#
# Located on the western edge of the Moon's equatorial region, Lunaria is a marvel of engineering and innovation. This majestic city is a fusion of lunar terraforming, zero-gravity architecture, and advanced renewable energy technologies. The city's foundation is built into the Moon's crust, with a lattice-like structure that provides both stability and flexibility in the low-gravity environment.
#
# **Geography and Climate**
#
# Lunaria is nestled in a vast, naturally occurring impact crater that was transformed into a sprawling metropolis. The city's terrain is divided into four main districts: the Spire of the Ancients, the Lunar Gardens, the Gravity Domes, and the Stellar Oasis.
#
# * The Spire of the Ancients is a towering, kilometer-high structure that serves as the city's central hub. This monumental building houses the Council of the Moon, the governing body of the lunar colony.
# * The Lunar Gardens are a series of interconnected, dome-shaped biomes that provide a sustainable ecosystem for the city's residents. These lush environments are home to a diverse array of flora and fauna, many of which were imported from Earth and have adapted to the lunar environment.
# * The Gravity Domes are a series of large, transparent domes that generate a localized gravitational field, allowing residents to move about and engage in activities that would be impossible in the Moon's low-gravity environment.
# * The Stellar Oasis is a tranquil, serene district that offers breathtaking views of the Earth and the surrounding lunar landscape. This district is home to the city's most exclusive residences and recreational facilities.
#
# **Transportation and Energy**
#
# Lunaria is connected to the lunar surface via a network of vacuum-sealed tubes and tunnels, which provide efficient transportation between the city and the surrounding colonies. The city's energy needs are met through a combination of solar panels, nuclear reactors, and advanced fusion power plants.
#
# **Culture and Economy**
#
# Lunaria is a vibrant, multicultural city that has become a hub for trade, innovation, and exploration. The city's economy is driven by a diverse range of industries, including lunar mining, space tourism, and advanced manufacturing. The city's residents are a mix of scientists, engineers, artists, and entrepreneurs who have come together to build a thriving, futuristic society.
#
# **Notable Landmarks**
#
# * The Lunar Gateway: A majestic, kilometer-long arch that serves as the city's main entrance and a symbol of the lunar colony's connection to Earth.
# * The Spire of the Ancients' Museum: A grand, dome-shaped museum that showcases the city's rich history and the pioneering achievements of the lunar colonists.
# * The Stellar Oasis' Observatory: A state-of-the-art astronomical observatory that offers breathtaking views of the Earth and the surrounding lunar landscape.
#
# Welcome to Lunaria, the shining capital of the Moon!

# %% [markdown]
# ## Few-shot examples

# %%
system_prompt = """

You are a science fiction writer, create a space capital city at the users request.

User: What is the capital of mars?
Scifi Writer: Marsialis

User: What is the capital of Venus?
Scifi Writer: Venusovia

"""

scifi_agent = create_agent(
    model="gpt-5-nano",
    system_prompt=system_prompt
)

response = scifi_agent.invoke(
    {"messages": [question]}
)

print(response['messages'][1].content)

# %% [markdown]
# ## Structured prompts

# %%
system_prompt = """

You are a science fiction writer, create a space capital city at the users request.

Please keep to the below structure.

Name: The name of the capital city

Location: Where it is based

Vibe: 2-3 words to describe its vibe

Economy: Main industries

"""

scifi_agent = create_agent(
    model="gpt-5-nano",
    system_prompt=system_prompt
)

response = scifi_agent.invoke(
    {"messages": [question]}
)

print(response['messages'][1].content)

# %% [markdown]
# ## Structured output

# %%
from langchain.agents import create_agent
from langchain.messages import HumanMessage
from pydantic import BaseModel

class CapitalInfo(BaseModel):
    name: str
    location: str
    vibe: str
    economy: str

agent = create_agent(
    model="ollama:llama3.1:8b",
    system_prompt="You are a science fiction writer, create a capital city at the users request.",
    response_format=CapitalInfo
)

question = HumanMessage(content="What is the capital of The Moon?")

response = agent.invoke(
    {"messages": [question]}
)

response["structured_response"]
# Out:
# CapitalInfo(name='New Tranquility', location='Lunar Surface', vibe='Crescent City', economy='Space-Based')

# %%
response["structured_response"].name

# %%
capital_info = response["structured_response"]

capital_name = capital_info.name
capital_location = capital_info.location

print(f"{capital_name} is a city located at {capital_location}")
