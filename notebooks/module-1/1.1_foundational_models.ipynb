# %%
from dotenv import load_dotenv

load_dotenv()
# Out:
# True

# %% [markdown]
# ## Initialising and invoking a model

# %%
from langchain_ollama import ChatOllama

model = ChatOllama(model="llama3.1:8b", temperature=0)

# %%
response = model.invoke("What's the capital of the Moon?")

response
# Out:
# AIMessage(content="There is no capital of the Moon. The Moon is a natural satellite that orbits the Earth, and it doesn't have a government, cities, or a capital. It's a rocky, airless body with no human settlements or infrastructure. So, there isn't a capital to speak of!", additional_kwargs={}, response_metadata={'model': 'llama3.1:8b', 'created_at': '2026-08-28T17:16:37.8058315Z', 'done': True, 'done_reason': 'stop', 'total_duration': 9854664500, 'load_duration': 10506600, 'prompt_eval_count': 18, 'prompt_eval_duration': 704950000, 'eval_count': 60, 'eval_duration': 8058756000, 'logprobs': None, 'model_name': 'llama3.1:8b', 'model_provider': 'ollama'}, id='lc_run--01a0495f-75a4-72f3-b8bc-272b0e655718-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 18, 'output_tokens': 60, 'total_tokens': 78})

# %%
print(response.content)
# Out:
# There is no capital of the Moon. The Moon is a natural satellite that orbits the Earth, and it doesn't have a government, cities, or a capital. It's a rocky, airless body with no human settlements or infrastructure. So, there isn't a capital to speak of!

# %%
from pprint import pprint

pprint(response.response_metadata)
# Out:
# {'created_at': '2026-08-28T17:14:53.243241Z',
#  'done': True,
#  'done_reason': 'stop',
#  'eval_count': 60,
#  'eval_duration': 7719431000,
#  'load_duration': 10714216100,
#  'logprobs': None,
#  'model': 'llama3.1:8b',
#  'model_name': 'llama3.1:8b',
#  'model_provider': 'ollama',
#  'prompt_eval_count': 18,
#  'prompt_eval_duration': 1082488000,
#  'total_duration': 19527671100}

# %% [markdown]
# ## Customising your Model

# %%
model = init_chat_model(
    model="gpt-5-nano",
    # Kwargs passed to the model:
    temperature=1.0
)

response = model.invoke("What's the capital of the Moon?")
print(response.content)

# %% [markdown]
# ## Model Providers

# %% [markdown]
# https://docs.langchain.com/oss/python/integrations/chat

# %%
model = init_chat_model(model="claude-sonnet-4-6")

response = model.invoke("What's the capital of the Moon?")
print(response.content)

# %%
from langchain_google_genai import ChatGoogleGenerativeAI

model = ChatGoogleGenerativeAI(model="gemini-3.1-flash-lite")

response = model.invoke("What's the capital of the Moon?")
print(response.content)

# %% [markdown]
# ## Initialising and invoking an agent

# %%
from langchain.agents import create_agent
from langchain_ollama import ChatOllama

model = ChatOllama(
    model="llama3.1:8b",
    temperature=0,
)

agent = create_agent(model=model)

# %%
agent = create_agent(
    model="ollama:llama3.1:8b"
)

# %%
agent = create_agent("ollama:llama3.1:8b")

# %%
from langchain.messages import HumanMessage

response = agent.invoke(
    {"messages": [HumanMessage(content="What's the capital of the Moon?")]}
)

# %%
from pprint import pprint

pprint(response)
# Out:
# {'messages': [HumanMessage(content="What's the capital of the Moon?", additional_kwargs={}, response_metadata={}, id='06b39f3c-e2eb-4e46-8ac9-54578fd97f26'),
#               AIMessage(content="There is no capital of the Moon. The Moon is a natural satellite that orbits the Earth, and it doesn't have a government, laws, or a physical presence in the same way that a country does. It's a rocky, airless body with no permanent residents or infrastructure.\n\nSo, there isn't a capital city on the Moon. Would you like to know more about the Moon or space-related topics?", additional_kwargs={}, response_metadata={'model': 'llama3.1:8b', 'created_at': '2026-08-28T18:05:20.7395472Z', 'done': True, 'done_reason': 'stop', 'total_duration': 21911045700, 'load_duration': 10157126400, 'prompt_eval_count': 18, 'prompt_eval_duration': 670095000, 'eval_count': 84, 'eval_duration': 11077238000, 'logprobs': None, 'model_name': 'llama3.1:8b', 'model_provider': 'ollama'}, id='lc_run--01a0498b-e04a-7d71-ad9d-8a66181ae501-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 18, 'output_tokens': 84, 'total_tokens': 102})]}

# %%
print(response['messages'][-1].content)
# Out:
# There is no capital of the Moon. The Moon is a natural satellite that orbits the Earth, and it doesn't have a government, laws, or a physical presence in the same way that a country does. It's a rocky, airless body with no permanent residents or infrastructure.
#
# So, there isn't a capital city on the Moon. Would you like to know more about the Moon or space-related topics?

# %%
from langchain.messages import AIMessage

response = agent.invoke(
    {"messages": [HumanMessage(content="What's the capital of the Moon?"),
    AIMessage(content="The capital of the Moon is Luna City."),
    HumanMessage(content="Interesting, tell me more about Luna City")]}
)

pprint(response)
# Out:
# {'messages': [HumanMessage(content="What's the capital of the Moon?", additional_kwargs={}, response_metadata={}, id='a28c8d0b-3839-4f09-a656-b87bc101ef10'),
#               AIMessage(content='The capital of the Moon is Luna City.', additional_kwargs={}, response_metadata={}, id='d7ea0e0d-f580-41e8-aaac-da2b7f21c0e5', tool_calls=[], invalid_tool_calls=[]),
#               HumanMessage(content='Interesting, tell me more about Luna City', additional_kwargs={}, response_metadata={}, id='4b6333b3-4852-4675-b66d-78f4bf74f35a'),
#               AIMessage(content='I made a mistake earlier. There is no such city as Luna City on the Moon. The Moon is a natural satellite that does not have any permanent human settlements or cities. It is a barren, airless rock that has been visited by several spacecraft and astronauts, but it has no infrastructure or established human presence.\n\nSo, to correct my earlier response, there is no capital of the Moon.', additional_kwargs={}, response_metadata={'model': 'llama3.1:8b', 'created_at': '2026-08-28T18:07:04.0310156Z', 'done': True, 'done_reason': 'stop', 'total_duration': 11712059000, 'load_duration': 5943600, 'prompt_eval_count': 45, 'prompt_eval_duration': 1022462000, 'eval_count': 80, 'eval_duration': 10670353000, 'logprobs': None, 'model_name': 'llama3.1:8b', 'model_provider': 'ollama'}, id='lc_run--01a0498d-9b9c-7203-b413-c2e56b19de00-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 45, 'output_tokens': 80, 'total_tokens': 125})]}

# %% [markdown]
# ## Streaming Output

# %%
for token, metadata in agent.stream(
    {"messages": [HumanMessage(content="Tell me all about Luna City, the capital of the Moon")]},
    stream_mode="messages"
):

    # token is a message chunk with token content
    # metadata contains which node produced the token
    
    if token.content:  # Check if there's actual content
        print(token.content, end="", flush=True)  # Print token
# Out:
# I'm afraid I have some disappointing news for you.
#
# There is no Luna City, and the Moon does not have a capital city. The Moon is a natural satellite that orbits the Earth, and it does not have a human settlement or a governing body. While there have been several manned missions to the Moon as part of NASA's Apollo program in the late 1960s and early 1970s, there are no permanent human settlements or cities on the Moon.
#
# However, there are some concepts and proposals for lunar settlements and cities that have been put forward by private companies and space agencies. For example, NASA is currently planning to return humans to the Moon by 2024 as part of its Artemis program, with the goal of establishing a sustainable presence on the lunar surface. Private companies like SpaceX and Blue Origin are also working on lunar missions and proposals for lunar settlements.
#
# Some concepts for lunar settlements and cities that have been proposed or designed include:
#
# * SpaceX's Starship, which is a reusable spacecraft designed to take both people and cargo to the Moon and other destinations in the solar system.
# * NASA's Gateway, which is a lunar-orbiting space station that will serve as a base for scientific research, exploration, and development of the Moon's resources.
# * The Lunar Gateway, which is a proposed lunar-orbiting space station that will be used as a base for scientific research, exploration, and development of the Moon's resources.
# * The Moon Village, which is a proposed international lunar settlement that will be built through a collaboration between governments, companies, and individuals.
#
# These concepts and proposals are still in the early stages of development, and it's unclear what the future of lunar settlements and cities will look like. But it's an exciting area of research and development that has the potential to open up new opportunities for space exploration and resource utilization.
