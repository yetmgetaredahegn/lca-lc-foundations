# %%
from dotenv import load_dotenv

load_dotenv()
# Out:
# True

# %%
from dataclasses import dataclass

@dataclass
class ColourContext:
    favourite_colour: str = "blue"
    least_favourite_colour: str = "yellow"

# %%
from langchain.agents import create_agent

agent = create_agent(
    model="ollama:llama3.1:8b",
    context_schema=ColourContext  
)

# %%
from langchain.messages import HumanMessage

response = agent.invoke(
    {"messages": [HumanMessage(content="What is my favourite colour?")]},
    context=ColourContext()
)

# %%
from pprint import pprint

pprint(response)
# Out:
# {'messages': [HumanMessage(content='What is my favourite colour?', additional_kwargs={}, response_metadata={}, id='ba3cce7e-213a-454a-93b2-d505d512cd2b'),
#               AIMessage(content="I'm afraid I don't have any information about your favorite color! We've just started our conversation, and I don't have any prior knowledge about your preferences. Would you like to tell me what your favorite color is?", additional_kwargs={}, response_metadata={'model': 'llama3.1:8b', 'created_at': '2026-09-03T08:25:55.096261Z', 'done': True, 'done_reason': 'stop', 'total_duration': 18728105400, 'load_duration': 11173377700, 'prompt_eval_count': 16, 'prompt_eval_duration': 1147444000, 'eval_count': 46, 'eval_duration': 6398095000, 'logprobs': None, 'model_name': 'llama3.1:8b', 'model_provider': 'ollama'}, id='lc_run--01a0665f-996c-7b91-b8fc-26cc0dfdb14b-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 16, 'output_tokens': 46, 'total_tokens': 62})]}

# %% [markdown]
# ## Accessing Context

# %%
from langchain.tools import tool, ToolRuntime

@tool
def get_favourite_colour(runtime: ToolRuntime[ColourContext]) -> str:
    """Get the favourite colour of the user"""
    return runtime.context.favourite_colour

@tool
def get_least_favourite_colour(runtime: ToolRuntime[ColourContext]) -> str:
    """Get the least favourite colour of the user"""
    return runtime.context.least_favourite_colour

# %%
agent = create_agent(
    model="ollama:llama3.1:8b",
    tools=[get_favourite_colour, get_least_favourite_colour],
    context_schema=ColourContext
)

# %%
response = agent.invoke(
    {"messages": [HumanMessage(content="What is my favourite colour?")]},
    context=ColourContext()
)

pprint(response)
# Out:
# {'messages': [HumanMessage(content='What is my favourite colour?', additional_kwargs={}, response_metadata={}, id='30dca968-05e0-4095-876e-e48fead3bea0'),
#               AIMessage(content='', additional_kwargs={}, response_metadata={'model': 'llama3.1:8b', 'created_at': '2026-09-03T08:32:24.9740711Z', 'done': True, 'done_reason': 'stop', 'total_duration': 15346156200, 'load_duration': 12669858700, 'prompt_eval_count': 188, 'prompt_eval_duration': 635988000, 'eval_count': 15, 'eval_duration': 2021740000, 'logprobs': None, 'model_name': 'llama3.1:8b', 'model_provider': 'ollama'}, id='lc_run--01a06665-9999-7fc3-b17b-65ae7b944ddb-0', tool_calls=[{'name': 'get_favourite_colour', 'args': {}, 'id': 'f80c2573-4536-4a60-9ed8-0b91f6057ed2', 'type': 'tool_call'}], invalid_tool_calls=[], usage_metadata={'input_tokens': 188, 'output_tokens': 15, 'total_tokens': 203}),
#               ToolMessage(content='blue', name='get_favourite_colour', id='39e165da-657e-4d78-9fda-9d4b17653340', tool_call_id='f80c2573-4536-4a60-9ed8-0b91f6057ed2'),
#               AIMessage(content='The output of the tool call indicates that your favourite colour is blue.', additional_kwargs={}, response_metadata={'model': 'llama3.1:8b', 'created_at': '2026-09-03T08:32:27.3848002Z', 'done': True, 'done_reason': 'stop', 'total_duration': 2392469500, 'load_duration': 7805100, 'prompt_eval_count': 89, 'prompt_eval_duration': 373169000, 'eval_count': 15, 'eval_duration': 1990700000, 'logprobs': None, 'model_name': 'llama3.1:8b', 'model_provider': 'ollama'}, id='lc_run--01a06665-d59d-70d0-b020-5f167864751d-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 89, 'output_tokens': 15, 'total_tokens': 104})]}

# %%
response = agent.invoke(
    {"messages": [HumanMessage(content="What is my favourite colour?")]},
    context=ColourContext(favourite_colour="green")
)

pprint(response)
# Out:
# {'messages': [HumanMessage(content='What is my favourite colour?', additional_kwargs={}, response_metadata={}, id='120815e7-b33c-40cf-aef5-ad03d5c5a2ee'),
#               AIMessage(content='', additional_kwargs={}, response_metadata={'model': 'llama3.1:8b', 'created_at': '2026-09-03T09:17:12.167886Z', 'done': True, 'done_reason': 'stop', 'total_duration': 16221396000, 'load_duration': 13740425900, 'prompt_eval_count': 188, 'prompt_eval_duration': 620986000, 'eval_count': 15, 'eval_duration': 1841488000, 'logprobs': None, 'model_name': 'llama3.1:8b', 'model_provider': 'ollama'}, id='lc_run--01a0668e-9704-7c10-aec8-06bd87509205-0', tool_calls=[{'name': 'get_favourite_colour', 'args': {}, 'id': '12af31af-97a0-4e56-b960-a0ac97d8b2bb', 'type': 'tool_call'}], invalid_tool_calls=[], usage_metadata={'input_tokens': 188, 'output_tokens': 15, 'total_tokens': 203}),
#               ToolMessage(content='green', name='get_favourite_colour', id='9cb71075-7dc1-43b6-a5ee-af4de0b1f011', tool_call_id='12af31af-97a0-4e56-b960-a0ac97d8b2bb'),
#               AIMessage(content='Based on the tool call output, it appears that your favourite colour is green.', additional_kwargs={}, response_metadata={'model': 'llama3.1:8b', 'created_at': '2026-09-03T09:17:14.9679532Z', 'done': True, 'done_reason': 'stop', 'total_duration': 2784449900, 'load_duration': 6488900, 'prompt_eval_count': 89, 'prompt_eval_duration': 381611000, 'eval_count': 17, 'eval_duration': 2374132000, 'logprobs': None, 'model_name': 'llama3.1:8b', 'model_provider': 'ollama'}, id='lc_run--01a0668e-d675-7192-b9b6-6af0c75d3b6c-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 89, 'output_tokens': 17, 'total_tokens': 106})]}
